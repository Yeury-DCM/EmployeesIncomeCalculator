# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeury-DCM/EmployeesIncomeCalculator/blob/master/Inferencia_De_Ingresos_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Recopilación de 5 Nóminas

# %% [markdown]
# Importación librerías necearias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importación de Datasets crudos

# %%
#Se va omitir las primeras filas del documento para que lea desde que empiezan los cabezales de la columna en adelante

cassd_df = pd.read_excel('CASSD.xlsx', skiprows = 5)
edesur_df = pd.read_excel('EDESUR.xlsx', skiprows = 6)
indrhi_df = pd.read_excel('INDRHI.xlsx', skiprows = 19)
minerd_df = pd.read_excel('MINERD.xlsx', skiprows = 7)
uasd_df = pd.read_excel('UASD.xlsx', skiprows = 8)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#   NO. SEXO                     Nombre_apellido  \
# 0   1    M        Jose Horacio  Cabrera Tejada
# 1   2    F          ISABEL MARIA ULLOA PAYAMPS
# 2   3    F    Adela Jocelyn  Rosario Gutierrez
# 3   4    M  Franklin Alberto  Beltre Fernandez
# 4   5    F               Nadesha M  Paniagua M
#
#                                         Departamento  \
# 0                                           RECTORIA
# 1            DEPARTAMENTO DE PERSONAL ADMINISTRATIVO
# 2                                           RECTORIA
# 3                         DEPARTAMENTO DE TECNOLOGIA
# 4  DEPARTAMENTO DE COMPRA DE CONTRATACIONES DE BI...
#
#                                 Funcion_o_puesto      Estado      Desde  \
# 0  DIRECTOR GRAL DE TECNOLOGIA DE LA INFORMACION  DE CARRERA 1975-08-01
# ...

# %% [markdown]
# ## Procesar, Homogenizar y Limpiar la Data
